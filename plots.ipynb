# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

df = pd.read_csv('./transcriptions/database.csv')
new_df = df.apply(pd.Series.value_counts).loc[[" 'Yes'"," 'No'"]][['timetables','block_card','change_pw','appointment','login_issue','card_enable','change_residence_data','claim_report','card_services_purchase','unknown']]
new_df.fillna(0, inplace=True)
new_df = new_df.transpose()
df
# Out:
#     Index                  Name                  DoB change_pw block_card  \
# 0       0             'Unknown'            'Unknown'      'No'      'Yes'
# 1       1         'Peppe Rossi'            'Unknown'      'No'       'No'
# 2       2         'Marco Rossi'      '3 aprile 1942'     'Yes'       'No'
# 3       3             'Unknown'            'Unknown'      'No'       'No'
# 4       4         'Mario Rossi'     '11 febbraio 96'     'Yes'       'No'
# 5       5               'Verdi'            'Unknown'      'No'      'Yes'
# 6       6             'Unknown'            'Unknown'      'No'       'No'
# 7       7         'Mario Rossi'            'Unknown'      'No'       'No'
# 8       9             'Unknown'            'Unknown'      'No'       'No'
# 9      10   'Silvio Berlusconi'     '10 aprile 1440'     'Yes'       'No'
# 10     11         'Mario Rossi'            'Unknown'      'No'       'No'
# 11     12             'Unknown'            'Unknown'      'No'       'No'
# 12     16         'Carlo Rossi'   'primo marzo 1980'     'Yes'      'Yes'
#
#    timetables appointment login_issue card_enable change_residence_data  \
# 0        'No'        'No'        'No'        'No'                  'No'
# 1       'Yes'        'No'        'No'        'No'                  'No'
# 2        'No'        'No'        'No'        'No'                  'No'
# 3        'No'        'No'        'No'        'No'                  'No'
# 4        'No'       'Yes'        'No'        'No'                  'No'
# 5        'No'       'Yes'        'No'        'No'                  'No'
# 6       'Yes'        'No'        'No'        'No'                  'No'
# 7        'No'       'Yes'       'Yes'       'Yes'                  'No'
# 8       'Yes'        'No'        'No'        'No'                  'No'
# 9       'Yes'        'No'       'Yes'        'No'                  'No'
# 10       'No'       'Yes'        'No'        'No'                 'Yes'
# 11      'Yes'        'No'        'No'        'No'                  'No'
# 12      'Yes'       'Yes'        'No'        'No'                  'No'
#
#    claim_report card_services_purchase unknown
# 0          'No'                   'No'    'No'
# 1          'No'                   'No'    'No'
# 2          'No'                  'Yes'    'No'
# 3          'No'                   'No'    'No'
# 4          'No'                   'No'   'Yes'
# 5          'No'                   'No'   'Yes'
# 6          'No'                   'No'    'No'
# 7         'Yes'                   'No'   'Yes'
# 8          'No'                   'No'   'Yes'
# 9          'No'                   'No'   'Yes'
# 10         'No'                  'Yes'   'Yes'
# 11         'No'                   'No'    'No'
# 12         'No'                   'No'    'No'

# %%
new_df[" 'Yes'"].sort_values(ascending = False)
# Out:
# timetables                6.0
# unknown                   6.0
# appointment               5.0
# change_pw                 4.0
# block_card                3.0
# login_issue               2.0
# card_services_purchase    2.0
# card_enable               1.0
# change_residence_data     1.0
# claim_report              1.0
# Name:  'Yes', dtype: float64

# %%
fig = new_df[" 'Yes'"].sort_values(ascending = False).plot.bar(figsize=(13,8),fontsize=16,color = 'orange')
plt.title('Functionality Usage', fontsize = 24)
plt.show()

# %%
fig = new_df.plot.bar(stacked= True,figsize=(13,8),fontsize=16)
fig.legend(fontsize = 16)
plt.show()

# %%
def my_autopct(pct):
    return ('%1.0f%%' % pct) if pct > 0 else ''

figure, axis = plt.subplots(2,figsize=(10,5),dpi = 140)
ax1 = plt.subplot2grid((1,2),(0,0))
plt.pie(new_df[" 'Yes'"],autopct=my_autopct, pctdistance=.6, textprops={'color':"w"})
plt.legend(new_df.index, loc = 'lower left',bbox_to_anchor=(-.35,-.35))
plt.title('Most Used Services', color = 'white')

ax2 = plt.subplot2grid((1,2), (0, 1))

plt.pie(new_df[" 'No'"],autopct=my_autopct, pctdistance=.6, textprops={'color':"w"})
plt.legend(new_df.index, loc = 'lower left',bbox_to_anchor=(-.35,-.35))
plt.title('Unused Services', color = 'white')

plt.show()
