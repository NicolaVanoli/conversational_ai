# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

df = pd.read_csv('./transcriptions/database.csv')
new_df = df.apply(pd.Series.value_counts).loc[[" 'Yes'"," 'No'"]][['timetables','block_card','change_pw','appointment','login_issue','card_enable','change_residence_data','claim_report','card_services_purchase','unknown']]
new_df.fillna(0, inplace=True)
new_df = new_df.transpose()
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\Users\nicol\Desktop\Personal\conversational_ai\plots.ipynb Cell 1 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/nicol/Desktop/Personal/conversational_ai/plots.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> get_ipython().run_line_magic('matplotlib', 'inline')
#       <a href='vscode-notebook-cell:/c%3A/Users/nicol/Desktop/Personal/conversational_ai/plots.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nicol/Desktop/Personal/conversational_ai/plots.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> df = pd.read_csv('./transcriptions/database.csv')
# ...

# %%
new_df[" 'Yes'"].sort_values(ascending = False)
# Out:
# timetables                20.0
# change_pw                 18.0
# appointment               16.0
# unknown                   14.0
# login_issue               13.0
# block_card                10.0
# change_residence_data      5.0
# claim_report               3.0
# card_services_purchase     2.0
# card_enable                1.0
# Name:  'Yes', dtype: float64

# %%
fig = new_df[" 'Yes'"].sort_values(ascending = False).plot.bar(figsize=(13,8),fontsize=16,color = 'orange')
plt.title('Functionality Usage', fontsize = 24)
plt.show()

# %%
new_df
# Out:
#                          'Yes'   'No'
# timetables                24.0   27.0
# block_card                10.0   40.0
# change_pw                 23.0   23.0
# appointment               22.0   29.0
# login_issue               20.0   31.0
# card_enable                1.0   49.0
# change_residence_data      6.0   45.0
# claim_report               3.0   48.0
# card_services_purchase     2.0   48.0
# unknown                   17.0   31.0

# %%
fig = new_df.plot.bar(stacked= True,figsize=(13,8),fontsize=16)
fig.legend(fontsize = 16)
plt.show()

# %%
def my_autopct(pct):
    return ('%1.0f%%' % pct) if pct > 0 else ''

figure, axis = plt.subplots(2,figsize=(10,5),dpi = 140)
ax1 = plt.subplot2grid((1,2),(0,0))
plt.pie(new_df[" 'Yes'"],autopct=my_autopct, pctdistance=.6, textprops={'color':"w"})
plt.legend(new_df.index, loc = 'lower left',bbox_to_anchor=(-.3,.35), framealpha=0.01)
plt.title('Most Used Services', color = 'white')

# ax2 = plt.subplot2grid((1,2), (0, 1))

# plt.pie(new_df[" 'No'"],autopct=my_autopct, pctdistance=.6, textprops={'color':"w"})
# plt.legend(new_df.index, loc = 'lower left',bbox_to_anchor=(-.35,-.35))
# plt.title('Unused Services', color = 'white')

plt.show()
